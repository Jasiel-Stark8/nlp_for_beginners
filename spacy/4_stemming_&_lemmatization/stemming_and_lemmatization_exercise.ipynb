# %% [markdown]
# ###                     **Stemming and Lemmatization: Exercises**

# %% [markdown]
# - **Run this cell to import all necessary packages**

# %%
#let import necessary libraries and create the object

#for nltk
import nltk
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

#downloading all neccessary packages related to nltk
nltk.download('all')


#for spacy
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/singularity_engineer/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/singularity_engineer/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/singularity_engineer/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/singularity_engineer/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/singularity_engineer/nltk_data...
# ...

# %% [markdown]
# **Exercise1:**
# - Convert these list of words into base form using Stemming and Lemmatization and observe the transformations
# - Write a short note on the words that have different base words using stemming and Lemmatization

# %%
#using stemming in nltk
lst_words = ['running', 'painting', 'walking', 'dressing', 'likely', 'children', 'whom', 'good', 'ate', 'fishing']

stemmed_words = [stemmer.stem(word) for word in lst_words]
print(stemmed_words)
# Out:
# ['run', 'paint', 'walk', 'dress', 'like', 'children', 'whom', 'good', 'ate', 'fish']

# %%
#using lemmatization in spacy

doc = nlp("running painting walking dressing likely children who good ate fishing")

for token in doc:
    print(token.lemma_)
# Out:
# run
# paint
# walk
# dress
# likely
# child
# who
# good
# eat
# fishing

# %% [markdown]
# **Exercise2:**
#
# - convert the given text into it's base form using both stemming and lemmatization

# %%
text = """Latha is a very multi talented girl. She is good at many skills like dancing, running, singing, playing. She also likes eating Pav Bhagi. she has a 
habit of fishing and swimming too. Besides all this, she is a wonderful at cooking too.
"""

# %%
#using stemming in nltk
from nltk import word_tokenize
#step1: Word tokenizing
tokens = word_tokenize(text.strip())
print(tokens)

#step2: getting the base form for each token using stemmer
stemmed_words = [stemmer.stem(token) for token in tokens]
print(stemmed_words)


#step3: joining all words in a list into string using 'join()'

# way 1
# words = stemmed_words
# string = ' '.join(words)

# way 2
string = ' '.join(str(word) for word in stemmed_words)
string
# Out:
# ['Latha', 'is', 'a', 'very', 'multi', 'talented', 'girl', '.', 'She', 'is', 'good', 'at', 'many', 'skills', 'like', 'dancing', ',', 'running', ',', 'singing', ',', 'playing', '.', 'She', 'also', 'likes', 'eating', 'Pav', 'Bhagi', '.', 'she', 'has', 'a', 'habit', 'of', 'fishing', 'and', 'swimming', 'too', '.', 'Besides', 'all', 'this', ',', 'she', 'is', 'a', 'wonderful', 'at', 'cooking', 'too', '.']
# ['latha', 'is', 'a', 'veri', 'multi', 'talent', 'girl', '.', 'she', 'is', 'good', 'at', 'mani', 'skill', 'like', 'danc', ',', 'run', ',', 'sing', ',', 'play', '.', 'she', 'also', 'like', 'eat', 'pav', 'bhagi', '.', 'she', 'ha', 'a', 'habit', 'of', 'fish', 'and', 'swim', 'too', '.', 'besid', 'all', 'thi', ',', 'she', 'is', 'a', 'wonder', 'at', 'cook', 'too', '.']
# 'latha is a veri multi talent girl . she is good at mani skill like danc , run , sing , play . she also like eat pav bhagi . she ha a habit of fish and swim too . besid all thi , she is a wonder at cook too .'

# %%
#using lemmatisation in spacy

#step1: Creating the object for the given text
doc = nlp(text)

#step2: getting the base form for each token using spacy 'lemma_'
base_words = []
tokens = [token.lemma_ for token in doc]
base_words.append(tokens)

#step3: joining all words in a list into string using 'join()'
string = ' '.join(tokens)
string
# Out:
# 'Latha be a very multi talented girl . she be good at many skill like dancing , running , singing , play . she also like eat Pav Bhagi . she have a \n habit of fishing and swim too . besides all this , she be a wonderful at cook too . \n'
